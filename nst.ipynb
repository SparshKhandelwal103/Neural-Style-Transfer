# %% [markdown]
# <a href="https://colab.research.google.com/github/SparshKhandelwal103/Neural-Style-Transfer/blob/main/nst.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow_hub as hub
import tensorflow as tf
from matplotlib import pyplot as plt
import numpy as np
import cv2
import os
import time
from google.colab import files
uploaded = files.upload()


model = hub.load('https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/2')

def load_img(img_path, max_dim=512):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)

    shape = tf.cast(tf.shape(img)[:-1], tf.float32)
    long_dim = max(shape)
    scale = max_dim / long_dim
    img = img[tf.newaxis, :]
    return img

content_image = load_img('main3.jpg')
style_image = load_img('content2.jpg')

plt.subplot(1, 2, 1)
plt.imshow(np.squeeze(content_image))

plt.subplot(1, 2, 2)
plt.imshow(np.squeeze(style_image))
plt.show()
# Out:
#      <input type="file" id="files-5eb59ce9-47d3-4fc6-84f3-2e182e0d2188" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5eb59ce9-47d3-4fc6-84f3-2e182e0d2188">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
content_image.shape
# Out:
# TensorShape([1, 2340, 1080, 3])

# %%
import os

def load_img_safe(img_path, max_dim=512):
    if not os.path.exists(img_path):
        raise FileNotFoundError(f"Image not found: {img_path}")

# %%
stylized_image = model(tf.constant(content_image), tf.constant(style_image))[0]
plt.imshow(np.squeeze(stylized_image))
plt.show()

# %%
tf.keras.utils.save_img("stylized_image.jpg", stylized_image.numpy().squeeze())
from google.colab import files
files.download("stylized_image.jpg")
